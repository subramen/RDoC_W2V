# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import re
import numpy as np
from collections import defaultdict

from gensim.test.utils import common_texts
from gensim.models import Word2Vec

# %% [markdown]
# ## Read SQL output into DF

# %%
def get_df_from_psv(fout=None):
    with open('data/output.psv', encoding="utf-8") as f:
        strr = f.read()
    df_str = re.sub(r'\n(?![0-9])', ' ', strr)

    df = pd.read_csv(io.StringIO(df_str), sep='|', error_bad_lines=False) #bad lines: [4399, 170914, 247161, 264812, 384966, 400521, 522365, 527597, 651243, 747036]

    # at least one row had the title in label col. 
    df.art_arttitle = np.where(df.art_arttitle.isnull() & df.label.notnull(), df.label, df.art_arttitle)

    df.columns = ['pmid', 'title', 'abstract', 'label']
    df.abstract = df.abstract.fillna('')

    # combine sectioned abstracts
    s=df.pmid.value_counts()
    mult_pmid = df[df.pmid.isin(s.index[s>1])]
    single_pmid = df[~df.pmid.isin(s.index[s>1])]
    mult_pmid2 = mult_pmid.groupby(['pmid']).abstract.transform(lambda x: ' '.join(x))
    mult_pmid['abstract'] = mult_pmid2
    mult_pmid = mult_pmid.drop_duplicates(subset=['pmid','abstract'])
    data_df = single_pmid.append(mult_pmid)

    data_df['content'] = np.where(data_df.title!=data_df.abstract, data_df.title+' '+data_df.abstract, data_df.abstract)

    if not fout:
        import datetime
        fout = "data/datadf_"+str(datetime.datetime.now()).replace(' ','_').replace(':','')+".pkl"
    data_df.to_pickle(fout)

    return data_df

# %% [markdown]
# ## Remove stopwords
# Hyphens - While generating hyperspace, tokenize word into nonhyphenated constituents. When looking up, sum up vecs of each constituent

# %%
def remove_stopwords(s):
    STOPWORDS = stopwords.words('english')+["'s", "’s"]+[x.capitalize() for x in stopwords.words('english')]
    
    s = re.sub(r'([a-zA-Z])[\-\/]([a-zA-Z])', r'\1 \2', s) # split hyphenated and slashed words
    s = re.sub(r'[^A-Za-z\s\(\)]+', '', s)
    tokens = word_tokenize(s)
    okstr = ' '.join([x for x in tokens if x in ['(',')'] or x not in STOPWORDS and len(x)>1])
    #only remove parentheses which are empty
    okstr = re.sub(r'\(\s*\)','',okstr)
    return okstr

# %% [markdown]
# ## Identify abbreviation full-forms from text, and expand

# %%
ABBR_LIST = defaultdict(list)
def abbr_expander(s):   
    res = re.findall(r'\(\s?[A-Z]\s?[A-Za-z]+\s?\)', s) # Misses acronyms with hyphen
    outs = s
    retstr = ''
    for abbr in res:
        ix = s.index(abbr)
        abbr_clean = re.sub(r'[^A-Za-z]', '', abbr) # keep only letters, discard all other chars
        abbr_len = len(re.sub(r'[a-z]','',abbr_clean)) # Number of capital letters ~ number of tokens to look back for expansion
        if abbr_clean[-1]=='s': abbr_len-=1 # Singularing a plural acronym
        # When looking for expansion candidates, consider (-) and (/) as word-breaks
        expanded = ' '.join(s[ix-1::-1][::-1].rstrip().split(' ')[-abbr_len:]) # identify possible candidates for expansion from preivous abbr_len words
        ABBR_LIST[abbr_clean].append(expanded)
        outs = outs.replace(' '+abbr, '') # Remove first instance of abbreviation before expanding other instances
        if abbr_clean[-1]=='s':
            outs = outs.replace(abbr_clean[:-1], expanded)
        else:
            outs = outs.replace(abbr_clean, expanded) 
        
    return outs

# %% [markdown]
# ## Get doc-per-line file

# %%
def clean_line_generator():
    data_df = get_df_from_psv()
    for abst in iter(data_df.content):
        abst = abbr_expander(abst)
        # Make post-period uppercase chars lower
        abst = re.sub(r"(?<=\. )[A-Z]",lambda t:t.group().lower(), abst)
        abst = remove_stopwords(abst)
        f.write(abst+'\n')

# %% [markdown]
# # TODO : Tag and keep only NOUNS and NOUNPHRASES

# %% [markdown]
# ## Generator (iterator) for reading abstracts

# %%
class sentenceGenerator:
    def __init__(self, f, limit=None):
        self.f=f
        self.li = limit
    def __iter__(self):
        c=0
        for l in open(self.f):
            if self.li and c>=self.li:
                break
            c+=1
            yield l.split()

# %%
import time
start = time.time()
fname = 'data/oapl_sample.txt'
sg=sentenceGenerator(fname)
model = Word2Vec(sg, size=100, window=5, min_count=1, workers=4)
word_vectors = model.wv

duration = time.time()-start
print(duration)
# Out:
# 5.824838876724243

# %%
word_vectors.vocab
# Out:
# {'Buccal': <gensim.models.keyedvectors.Vocab at 0x1c85cc28208>,
#  'cellulitis': <gensim.models.keyedvectors.Vocab at 0x1c85cc28508>,
#  'reevaluated': <gensim.models.keyedvectors.Vocab at 0x1c85cc28a08>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x1c85cc28588>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x1c85c880088>,
#  'prospectively': <gensim.models.keyedvectors.Vocab at 0x1c85c880748>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x1c85c880248>,
#  'buccal': <gensim.models.keyedvectors.Vocab at 0x1c85c880288>,
#  'median': <gensim.models.keyedvectors.Vocab at 0x1c85c8806c8>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x1c85c8803c8>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x1c85c8808c8>,
#  'Fifty': <gensim.models.keyedvectors.Vocab at 0x1c85c880c48>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1c85c880d08>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x1c85c880c88>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x1c85c880808>,
#  'bacteremic': <gensim.models.keyedvectors.Vocab at 0x1c85c887288>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1c85c887788>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1c85c887e88>,
#  'meningeal': <gensim.models.keyedvectors.Vocab at 0x1c85c8872c8>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x1c85c8873c8>,
#  'symptoms': <gensim.models.keyedvectors.Vocab at 0x1c85c887088>,
#  'concomitant': <gensim.models.keyedvectors.Vocab at 0x1c85c8870c8>,
#  'meningitis': <gensim.models.keyedvectors.Vocab at 0x1c85c887108>,
#  'Cellulitis': <gensim.models.keyedvectors.Vocab at 0x1c85c887188>,
#  'aspirate': <gensim.models.keyedvectors.Vocab at 0x1c85c8871c8>,
#  'cultures': <gensim.models.keyedvectors.Vocab at 0x1c85c887208>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x1c85c887248>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x1c85c887348>,
#  'urine': <gensim.models.keyedvectors.Vocab at 0x1c85c887408>,
#  'bacterial': <gensim.models.keyedvectors.Vocab at 0x1c85c7794c8>,
#  'antigen': <gensim.models.keyedvectors.Vocab at 0x1c85a81ae08>,
#  'tests': <gensim.models.keyedvectors.Vocab at 0x1c85a81ab88>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x1c857b63748>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1c85a811cc8>,
#  'etiologic': <gensim.models.keyedvectors.Vocab at 0x1c85a8302c8>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x1c85c95cec8>,
#  'Infections': <gensim.models.keyedvectors.Vocab at 0x1c85c95cd48>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1c859e60908>,
#  'bacteria': <gensim.models.keyedvectors.Vocab at 0x1c852c5e188>,
#  'clinically': <gensim.models.keyedvectors.Vocab at 0x1c852c5e108>,
#  'indistinguishable': <gensim.models.keyedvectors.Vocab at 0x1c859e5d888>,
#  'Haemophilus': <gensim.models.keyedvectors.Vocab at 0x1c85b488b48>,
#  'influenzae': <gensim.models.keyedvectors.Vocab at 0x1c859dbd7c8>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1c85a3d4048>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1c85a3d45c8>,
#  'cheek': <gensim.models.keyedvectors.Vocab at 0x1c85c767f08>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x1c85c767d08>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x1c85c767a08>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x1c85c767d48>,
#  'otitis': <gensim.models.keyedvectors.Vocab at 0x1c85c767c88>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x1c85c767308>,
#  'ipsilateral': <gensim.models.keyedvectors.Vocab at 0x1c85c767288>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x1c85c767548>,
#  'pathogenesis': <gensim.models.keyedvectors.Vocab at 0x1c85c7673c8>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x1c85c767208>,
#  'involves': <gensim.models.keyedvectors.Vocab at 0x1c85c663488>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1c85c663f48>,
#  'mucous': <gensim.models.keyedvectors.Vocab at 0x1c85b586308>,
#  'membrane': <gensim.models.keyedvectors.Vocab at 0x1c85b586208>,
#  'invasion': <gensim.models.keyedvectors.Vocab at 0x1c85dd77088>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1c85dd770c8>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x1c85dd77a48>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x1c85dd777c8>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x1c85dd77208>,
#  'Gas': <gensim.models.keyedvectors.Vocab at 0x1c85dd77a08>,
#  'absorption': <gensim.models.keyedvectors.Vocab at 0x1c85dd773c8>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x1c85dd77388>,
#  'alert': <gensim.models.keyedvectors.Vocab at 0x1c85dd77708>,
#  'anesthetized': <gensim.models.keyedvectors.Vocab at 0x1c85dd77248>,
#  'rhesus': <gensim.models.keyedvectors.Vocab at 0x1c85dd77308>,
#  'monkeys': <gensim.models.keyedvectors.Vocab at 0x1c85dd77908>,
#  'monitored': <gensim.models.keyedvectors.Vocab at 0x1c85dd77148>,
#  'serial': <gensim.models.keyedvectors.Vocab at 0x1c85dd77188>,
#  'tympanograms': <gensim.models.keyedvectors.Vocab at 0x1c85c6351c8>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1c85c635388>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x1c85c635688>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x1c85c635508>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x1c85c635308>,
#  'cavity': <gensim.models.keyedvectors.Vocab at 0x1c85c635108>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x1c85c635f48>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1c85c635a48>,
#  'observation': <gensim.models.keyedvectors.Vocab at 0x1c85c635ac8>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x1c85c635c48>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x1c85c635548>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1c85c6359c8>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x1c85c635848>,
#  'fluctuations': <gensim.models.keyedvectors.Vocab at 0x1c85c635f88>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1c85c635888>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x1c85c635808>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x1c85c635908>,
#  'whereas': <gensim.models.keyedvectors.Vocab at 0x1c85c635788>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x1c85c635a08>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x1c85c635a88>,
#  'phase': <gensim.models.keyedvectors.Vocab at 0x1c85c635b08>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x1c85c635b88>,
#  'plateau': <gensim.models.keyedvectors.Vocab at 0x1c85c635c08>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x1c85c635c88>,
#  'mm': <gensim.models.keyedvectors.Vocab at 0x1c85c635d08>,
#  'HO': <gensim.models.keyedvectors.Vocab at 0x1c85c635d88>,
#  'composition': <gensim.models.keyedvectors.Vocab at 0x1c85c635f08>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x1c85c6352c8>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x1c85c635248>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x1c85c635348>,
#  'politzerization': <gensim.models.keyedvectors.Vocab at 0x1c85c6357c8>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1c85c635048>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1c85c635dc8>,
#  'compositions': <gensim.models.keyedvectors.Vocab at 0x1c85c635648>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1c85c635cc8>,
#  'magnitude': <gensim.models.keyedvectors.Vocab at 0x1c85c635d48>,
#  'Politzerization': <gensim.models.keyedvectors.Vocab at 0x1c85c6353c8>,
#  'resulted': <gensim.models.keyedvectors.Vocab at 0x1c85c635b48>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x1c85c635748>,
#  'pressures': <gensim.models.keyedvectors.Vocab at 0x1c85c929a48>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x1c85c929d08>,
#  'experimental': <gensim.models.keyedvectors.Vocab at 0x1c85c929e48>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x1c85c929cc8>,
#  'suggested': <gensim.models.keyedvectors.Vocab at 0x1c85c9294c8>,
#  'physiological': <gensim.models.keyedvectors.Vocab at 0x1c85c929908>,
#  'gases': <gensim.models.keyedvectors.Vocab at 0x1c85c929988>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x1c85c929548>,
#  'surrounding': <gensim.models.keyedvectors.Vocab at 0x1c85c929388>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x1c85c929648>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1c85c929c08>,
#  'decreases': <gensim.models.keyedvectors.Vocab at 0x1c85c9298c8>,
#  'considerably': <gensim.models.keyedvectors.Vocab at 0x1c85c9295c8>,
#  'Based': <gensim.models.keyedvectors.Vocab at 0x1c85c929208>,
#  'findings': <gensim.models.keyedvectors.Vocab at 0x1c85c929448>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x1c85c9290c8>,
#  'mechanism': <gensim.models.keyedvectors.Vocab at 0x1c85c929148>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x1c85c929848>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x1c85c929c88>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x1c85c929d48>,
#  'Potential': <gensim.models.keyedvectors.Vocab at 0x1c85c929dc8>,
#  'levocetirizine': <gensim.models.keyedvectors.Vocab at 0x1c85c929e88>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x1c85c929ec8>,
#  'nasal': <gensim.models.keyedvectors.Vocab at 0x1c85c929f08>,
#  'congestion': <gensim.models.keyedvectors.Vocab at 0x1c85c929f88>,
#  'Nasal': <gensim.models.keyedvectors.Vocab at 0x1c85c929fc8>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1c85c9297c8>,
#  'troublesome': <gensim.models.keyedvectors.Vocab at 0x1c85c929e08>,
#  'symptom': <gensim.models.keyedvectors.Vocab at 0x1c85c929f48>,
#  'allergic': <gensim.models.keyedvectors.Vocab at 0x1c85c929a08>,
#  'rhinitis': <gensim.models.keyedvectors.Vocab at 0x1c85a51b7c8>,
#  'impairs': <gensim.models.keyedvectors.Vocab at 0x1c85c639dc8>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x1c85c6391c8>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x1c85c639b08>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x1c85c639488>,
#  'breathing': <gensim.models.keyedvectors.Vocab at 0x1c85c639288>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x1c85c6390c8>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x1c85a810388>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x1c85c8d4cc8>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x1c85c8d4c88>,
#  'esteem': <gensim.models.keyedvectors.Vocab at 0x1c85c7630c8>,
#  'impaired': <gensim.models.keyedvectors.Vocab at 0x1c85c763b08>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x1c85c763488>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1c85c763688>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x1c85c763048>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x1c85c763b88>,
#  'Traditionally': <gensim.models.keyedvectors.Vocab at 0x1c85c763d88>,
#  'intranasal': <gensim.models.keyedvectors.Vocab at 0x1c85c763c88>,
#  'steroids': <gensim.models.keyedvectors.Vocab at 0x1c85c763988>,
#  'potent': <gensim.models.keyedvectors.Vocab at 0x1c85c7632c8>,
#  'anti': <gensim.models.keyedvectors.Vocab at 0x1c85c763288>,
#  'inflammatory': <gensim.models.keyedvectors.Vocab at 0x1c85c763088>,
#  'properties': <gensim.models.keyedvectors.Vocab at 0x1c85c7631c8>,
#  'vasoconstrictors': <gensim.models.keyedvectors.Vocab at 0x1c85c763448>,
#  'utilized': <gensim.models.keyedvectors.Vocab at 0x1c85c63d6c8>,
#  'relieving': <gensim.models.keyedvectors.Vocab at 0x1c85c63d808>,
#  'passages': <gensim.models.keyedvectors.Vocab at 0x1c85c63d8c8>,
#  'inflamed': <gensim.models.keyedvectors.Vocab at 0x1c85c63d948>,
#  'congested': <gensim.models.keyedvectors.Vocab at 0x1c85c63db08>,
#  'mucosal': <gensim.models.keyedvectors.Vocab at 0x1c85c63d708>,
#  'tissues': <gensim.models.keyedvectors.Vocab at 0x1c85c63d148>,
#  'Recent': <gensim.models.keyedvectors.Vocab at 0x1c85c63d048>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x1c85c63df88>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1c85c63df08>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x1c85c63da88>,
#  'antihistamines': <gensim.models.keyedvectors.Vocab at 0x1c85c63d4c8>,
#  'demonstrated': <gensim.models.keyedvectors.Vocab at 0x1c85c63d108>,
#  'decongestant': <gensim.models.keyedvectors.Vocab at 0x1c85c63dc08>,
#  'seasonal': <gensim.models.keyedvectors.Vocab at 0x1c85c63d988>,
#  'chronic': <gensim.models.keyedvectors.Vocab at 0x1c85c63da08>,
#  'lasting': <gensim.models.keyedvectors.Vocab at 0x1c85cbe4688>,
#  'perennial': <gensim.models.keyedvectors.Vocab at 0x1c85cbe4f48>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x1c85cbe4a48>,
#  'aims': <gensim.models.keyedvectors.Vocab at 0x1c85cbe42c8>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x1c85cbe4908>,
#  'efficacy': <gensim.models.keyedvectors.Vocab at 0x1c85cbe4048>,
#  'antihistamine': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc888>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc3c8>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc588>,
#  'settings': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc2c8>,
#  'Comparisons': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc308>,
#  'placebo': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc0c8>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc948>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1c85c8dc188>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x1c85c939148>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x1c85c6424c8>,
#  'practitioners': <gensim.models.keyedvectors.Vocab at 0x1c85c6425c8>,
#  'differentiate': <gensim.models.keyedvectors.Vocab at 0x1c85c642548>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x1c85c642588>,
#  'Placental': <gensim.models.keyedvectors.Vocab at 0x1c85c642408>,
#  'ischemia': <gensim.models.keyedvectors.Vocab at 0x1c85c642248>,
#  'induced': <gensim.models.keyedvectors.Vocab at 0x1c85c642508>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x1c85b5fca08>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x1c85a393c88>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1c85c8dbac8>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x1c85c8dbc48>,
#  'cerebrovascular': <gensim.models.keyedvectors.Vocab at 0x1c85c8dbfc8>,
#  'permeability': <gensim.models.keyedvectors.Vocab at 0x1c85c8db908>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x1c85c8db8c8>,
#  'tumor': <gensim.models.keyedvectors.Vocab at 0x1c85c8db048>,
#  'necrosis': <gensim.models.keyedvectors.Vocab at 0x1c85c762f48>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x1c85c7620c8>,
#  'Cerebrovascular': <gensim.models.keyedvectors.Vocab at 0x1c85c7629c8>,
#  'complications': <gensim.models.keyedvectors.Vocab at 0x1c85c8d6c48>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x1c85c8d6648>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x1c85c8d6fc8>,
#  'encephalopathies': <gensim.models.keyedvectors.Vocab at 0x1c85c8d6308>,
#  'characteristic': <gensim.models.keyedvectors.Vocab at 0x1c85c8d64c8>,
#  'preeclampsia': <gensim.models.keyedvectors.Vocab at 0x1c85c887488>,
#  'contribute': <gensim.models.keyedvectors.Vocab at 0x1c85c8874c8>,
#  'eclampsia': <gensim.models.keyedvectors.Vocab at 0x1c85c887508>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x1c85c8875c8>,
#  'deaths': <gensim.models.keyedvectors.Vocab at 0x1c85c887608>,
#  'Circulating': <gensim.models.keyedvectors.Vocab at 0x1c85c887688>,
#  'elevated': <gensim.models.keyedvectors.Vocab at 0x1c85c8876c8>,
#  'preeclamptic': <gensim.models.keyedvectors.Vocab at 0x1c85c887708>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x1c85c8877c8>,
#  'infusion': <gensim.models.keyedvectors.Vocab at 0x1c85c8879c8>,
#  'pregnant': <gensim.models.keyedvectors.Vocab at 0x1c85c887b88>,
#  'rats': <gensim.models.keyedvectors.Vocab at 0x1c85c887c08>,
#  'mimics': <gensim.models.keyedvectors.Vocab at 0x1c85c887c48>,
#  'characteristics': <gensim.models.keyedvectors.Vocab at 0x1c85c887c88>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x1c85c887cc8>,
#  'mechanistic': <gensim.models.keyedvectors.Vocab at 0x1c85c887d08>,
#  'promote': <gensim.models.keyedvectors.Vocab at 0x1c85c887d88>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x1c85c887dc8>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x1c85c887e08>,
#  'vasculature': <gensim.models.keyedvectors.Vocab at 0x1c85c887f88>,
#  'pregnancy': <gensim.models.keyedvectors.Vocab at 0x1c85c887808>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x1c85c887a08>,
#  'unclear': <gensim.models.keyedvectors.Vocab at 0x1c85c887848>,
#  'tested': <gensim.models.keyedvectors.Vocab at 0x1c85c887888>,
#  'hypothesis': <gensim.models.keyedvectors.Vocab at 0x1c85cc2ac88>,
#  'contributes': <gensim.models.keyedvectors.Vocab at 0x1c85cc2aa88>,
#  'abnormalities': <gensim.models.keyedvectors.Vocab at 0x1c85cc2ab88>,
#  'placental': <gensim.models.keyedvectors.Vocab at 0x1c85cc2ad48>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a188>,
#  'infusing': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a2c8>,
#  'ng': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a988>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1c85cc2aa48>,
#  'ip': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a908>,
#  'gestational': <gensim.models.keyedvectors.Vocab at 0x1c85cc2ab08>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x1c85cc2af88>,
#  'mimic': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a348>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a1c8>,
#  'arterial': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a308>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a748>,
#  'cerebrum': <gensim.models.keyedvectors.Vocab at 0x1c85cc2a408>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x1c85c63bec8>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x1c85c63b308>,
#  'barrier': <gensim.models.keyedvectors.Vocab at 0x1c85c63b748>,
#  'posterior': <gensim.models.keyedvectors.Vocab at 0x1c85c88f948>,
#  'assessed': <gensim.models.keyedvectors.Vocab at 0x1c85c88fa08>,
#  'endogenous': <gensim.models.keyedvectors.Vocab at 0x1c85c88fa48>,
#  'mediating': <gensim.models.keyedvectors.Vocab at 0x1c85c88fac8>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x1c85c88fb48>,
#  'reducing': <gensim.models.keyedvectors.Vocab at 0x1c85c88fbc8>,
#  'uterine': <gensim.models.keyedvectors.Vocab at 0x1c85c88fe48>,
#  'perfusion': <gensim.models.keyedvectors.Vocab at 0x1c85c88f308>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x1c85c88f4c8>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x1c85c88f508>,
#  'soluble': <gensim.models.keyedvectors.Vocab at 0x1c85c88f088>,
#  'receptor': <gensim.models.keyedvectors.Vocab at 0x1c85c88fcc8>,
#  'etanercept': <gensim.models.keyedvectors.Vocab at 0x1c85c88f988>,
#  'mg': <gensim.models.keyedvectors.Vocab at 0x1c85c88f348>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x1c85c88f608>,
#  'sc': <gensim.models.keyedvectors.Vocab at 0x1c85c88fd48>,
#  'Etanercept': <gensim.models.keyedvectors.Vocab at 0x1c85c88ff48>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x1c85c88ff88>,
#  'mediated': <gensim.models.keyedvectors.Vocab at 0x1c85c88ffc8>,
#  'ischemic': <gensim.models.keyedvectors.Vocab at 0x1c85c88f5c8>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x1c85c88f148>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x1c85c88f288>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x1c85c88fe08>,
#  'mechanistically': <gensim.models.keyedvectors.Vocab at 0x1c85c88fe88>,
#  'edema': <gensim.models.keyedvectors.Vocab at 0x1c85c88f648>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x1c85c88f9c8>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x1c85c88fa88>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x1c85c88fb88>,
#  'complicated': <gensim.models.keyedvectors.Vocab at 0x1c85c88fd08>,
#  'Recurrent': <gensim.models.keyedvectors.Vocab at 0x1c85c88f048>,
#  'ovarian': <gensim.models.keyedvectors.Vocab at 0x1c85c88f0c8>,
#  'carcinoma': <gensim.models.keyedvectors.Vocab at 0x1c85c88f188>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1c85c88f1c8>,
#  'surgeryThe': <gensim.models.keyedvectors.Vocab at 0x1c85c88f208>,
#  'cytoreductive': <gensim.models.keyedvectors.Vocab at 0x1c85c88f248>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x1c85c88f2c8>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1c85c88f388>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x1c85c88f3c8>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x1c85c88f448>,
#  'Minimal': <gensim.models.keyedvectors.Vocab at 0x1c85c88fc48>,
#  'residual': <gensim.models.keyedvectors.Vocab at 0x1c85c88f8c8>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x1c85c88f588>,
#  'translates': <gensim.models.keyedvectors.Vocab at 0x1c85c88f688>,
#  'improved': <gensim.models.keyedvectors.Vocab at 0x1c85c88f708>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x1c85c88f748>,
#  'adjuvant': <gensim.models.keyedvectors.Vocab at 0x1c85c88f788>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x1c85c88f7c8>,
#  'survival': <gensim.models.keyedvectors.Vocab at 0x1c85c88f808>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1c85c88fec8>,
#  'clinical': <gensim.models.keyedvectors.Vocab at 0x1c85cc298c8>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1c85cc29e48>,
#  'approaches': <gensim.models.keyedvectors.Vocab at 0x1c85cc29648>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1c85cc29448>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x1c85c884c48>,
#  'detecting': <gensim.models.keyedvectors.Vocab at 0x1c85c884188>,
#  'recurrent': <gensim.models.keyedvectors.Vocab at 0x1c85c884a88>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1c85c884748>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x1c85c884888>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x1c85c884688>,
#  'pelvic': <gensim.models.keyedvectors.Vocab at 0x1c85c884348>,
#  'examination': <gensim.models.keyedvectors.Vocab at 0x1c85c8845c8>,
#  'CA': <gensim.models.keyedvectors.Vocab at 0x1c85c884588>,
#  'imaging': <gensim.models.keyedvectors.Vocab at 0x1c85c884b88>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1c85c8acd88>,
#  'computerized': <gensim.models.keyedvectors.Vocab at 0x1c85c8acb88>,
#  'tomography': <gensim.models.keyedvectors.Vocab at 0x1c85c8acdc8>,
#  'magnetic': <gensim.models.keyedvectors.Vocab at 0x1c85c8aca88>,
#  'resonance': <gensim.models.keyedvectors.Vocab at 0x1c85c8ace48>,
#  'positron': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac648>,
#  'emission': <gensim.models.keyedvectors.Vocab at 0x1c85c8acf48>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac108>,
#  'recurrence': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac388>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac048>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac948>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x1c85c8acb48>,
#  'therapy': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac148>,
#  'macronodular': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac188>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac688>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac7c8>,
#  'candidates': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac808>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x1c85c8acf08>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac8c8>,
#  'Data': <gensim.models.keyedvectors.Vocab at 0x1c85c8ac988>,
#  'cytoreduction': <gensim.models.keyedvectors.Vocab at 0x1c85c8aca48>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x1c85c882b88>,
#  'chemotherapy': <gensim.models.keyedvectors.Vocab at 0x1c85c882a08>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x1c85c882ac8>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x1c85c882b08>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x1c85c8829c8>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x1c85c8826c8>,
#  'Survival': <gensim.models.keyedvectors.Vocab at 0x1c85c882608>,
#  'optimized': <gensim.models.keyedvectors.Vocab at 0x1c85c882988>,
#  'microscopic': <gensim.models.keyedvectors.Vocab at 0x1c85c882fc8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1c85c882f88>,
#  'recognized': <gensim.models.keyedvectors.Vocab at 0x1c85c882908>,
#  'surgical': <gensim.models.keyedvectors.Vocab at 0x1c85c882cc8>,
#  'morbidity': <gensim.models.keyedvectors.Vocab at 0x1c85c882bc8>,
#  'Therefore': <gensim.models.keyedvectors.Vocab at 0x1c85c882c88>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1c85c882508>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x1c85c8823c8>,
#  'gynecologic': <gensim.models.keyedvectors.Vocab at 0x1c85c882408>,
#  'oncology': <gensim.models.keyedvectors.Vocab at 0x1c85c8824c8>,
#  'surgeon': <gensim.models.keyedvectors.Vocab at 0x1c85c882d08>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x1c85c882d48>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x1c85c882648>,
#  'obtaining': <gensim.models.keyedvectors.Vocab at 0x1c85c882688>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x1c85c8827c8>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x1c85c882808>,
#  'consent': <gensim.models.keyedvectors.Vocab at 0x1c85c882948>,
#  'relaying': <gensim.models.keyedvectors.Vocab at 0x1c85c882f48>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x1c85c882e08>,
#  'expectations': <gensim.models.keyedvectors.Vocab at 0x1c85c882348>,
#  'Visual': <gensim.models.keyedvectors.Vocab at 0x1c85c882088>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x1c85c8820c8>,
#  'intoxication': <gensim.models.keyedvectors.Vocab at 0x1c85c882148>,
#  'Foster': <gensim.models.keyedvectors.Vocab at 0x1c85c8821c8>,
#  'Kennedy': <gensim.models.keyedvectors.Vocab at 0x1c85c882248>,
#  'Syndrome': <gensim.models.keyedvectors.Vocab at 0x1c85c8822c8>,
#  'uncommon': <gensim.models.keyedvectors.Vocab at 0x1c85c882308>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x1c85c8abfc8>,
#  'cited': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab348>,
#  'confusing': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab6c8>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x1c85c8abc88>,
#  'presents': <gensim.models.keyedvectors.Vocab at 0x1c85c8abec8>,
#  'lucid': <gensim.models.keyedvectors.Vocab at 0x1c85c8abf08>,
#  'definition': <gensim.models.keyedvectors.Vocab at 0x1c85c8abf48>,
#  'syndrome': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab7c8>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab648>,
#  'diagnostic': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab048>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab148>,
#  'tenacious': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab188>,
#  'historical': <gensim.models.keyedvectors.Vocab at 0x1c85c8abac8>,
#  'roots': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab448>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab208>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab808>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab848>,
#  'congeners': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab988>,
#  'discuss': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab9c8>,
#  'misnomers': <gensim.models.keyedvectors.Vocab at 0x1c85c8abc48>,
#  'illustrative': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab688>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1c85c8abb48>,
#  'Mixed': <gensim.models.keyedvectors.Vocab at 0x1c85c8abb88>,
#  'cryoglobulinemia': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab388>,
#  'hepatitis': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab3c8>,
#  'infection': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab488>,
#  'clinicopathologic': <gensim.models.keyedvectors.Vocab at 0x1c85c8ab508>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x1c85c888d08>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x1c85c888e08>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x1c85c8885c8>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1c85c888548>,
#  'mixed': <gensim.models.keyedvectors.Vocab at 0x1c85c888a88>,
#  'infected': <gensim.models.keyedvectors.Vocab at 0x1c85c888688>,
#  'pertinent': <gensim.models.keyedvectors.Vocab at 0x1c85c888708>,
#  'serologic': <gensim.models.keyedvectors.Vocab at 0x1c85c888788>,
#  'pathological': <gensim.models.keyedvectors.Vocab at 0x1c85c888f08>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1c85c888748>,
#  'attributable': <gensim.models.keyedvectors.Vocab at 0x1c85c888888>,
#  'MC': <gensim.models.keyedvectors.Vocab at 0x1c85c888908>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x1c85c888a48>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x1c85c888048>,
#  'HCV': <gensim.models.keyedvectors.Vocab at 0x1c85c888608>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x1c85c888ac8>,
#  'prevalence': <gensim.models.keyedvectors.Vocab at 0x1c85c888b08>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x1c85c888b88>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x1c85c888c88>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x1c85c888448>,
#  'Europe': <gensim.models.keyedvectors.Vocab at 0x1c85c888dc8>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1c85c888088>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x1c85c888108>,
#  'requirement': <gensim.models.keyedvectors.Vocab at 0x1c85c8881c8>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x1c85c888208>,
#  'cryocrit': <gensim.models.keyedvectors.Vocab at 0x1c85c888248>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1c85c8882c8>,
#  'cryoglobulins': <gensim.models.keyedvectors.Vocab at 0x1c85c888308>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x1c85c888348>,
#  'deposited': <gensim.models.keyedvectors.Vocab at 0x1c85c888388>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x1c85c8883c8>,
#  'kidney': <gensim.models.keyedvectors.Vocab at 0x1c85c888488>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x1c85c888588>,
#  'mechanisms': <gensim.models.keyedvectors.Vocab at 0x1c85c888d48>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x1c85c8884c8>,
#  'uncertain': <gensim.models.keyedvectors.Vocab at 0x1c85c888fc8>,
#  'Although': <gensim.models.keyedvectors.Vocab at 0x1c85c888808>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x1c85c8888c8>,
#  'enrichment': <gensim.models.keyedvectors.Vocab at 0x1c85c891248>,
#  'RNA': <gensim.models.keyedvectors.Vocab at 0x1c85c891a88>,
#  'cryoprecipitates': <gensim.models.keyedvectors.Vocab at 0x1c85c891ac8>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1c85c891b08>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1c85c891b48>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x1c85c891b88>,
#  'fundamental': <gensim.models.keyedvectors.Vocab at 0x1c85c891348>,
#  'pathogenic': <gensim.models.keyedvectors.Vocab at 0x1c85c891d88>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x1c85c891dc8>,
#  'Finally': <gensim.models.keyedvectors.Vocab at 0x1c85c891e08>,
#  'beneficial': <gensim.models.keyedvectors.Vocab at 0x1c85c891e48>,
#  'vasculitic': <gensim.models.keyedvectors.Vocab at 0x1c85c891e88>,
#  'alpha': <gensim.models.keyedvectors.Vocab at 0x1c85c891f08>,
#  'interferon': <gensim.models.keyedvectors.Vocab at 0x1c85c891f48>,
#  'glucocorticoids': <gensim.models.keyedvectors.Vocab at 0x1c85c891f88>,
#  'immunosuppressants': <gensim.models.keyedvectors.Vocab at 0x1c85c891fc8>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x1c85c891748>,
#  'predictors': <gensim.models.keyedvectors.Vocab at 0x1c85c891288>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x1c85c891048>,
#  'distinguish': <gensim.models.keyedvectors.Vocab at 0x1c85c891088>,
#  'responders': <gensim.models.keyedvectors.Vocab at 0x1c85c8910c8>,
#  'nonresponders': <gensim.models.keyedvectors.Vocab at 0x1c85c891108>,
#  'Similarly': <gensim.models.keyedvectors.Vocab at 0x1c85c891148>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x1c85c891188>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x1c85c8911c8>,
#  'Severe': <gensim.models.keyedvectors.Vocab at 0x1c85c891208>,
#  'venous': <gensim.models.keyedvectors.Vocab at 0x1c85c891a48>,
#  'congestive': <gensim.models.keyedvectors.Vocab at 0x1c85c8917c8>,
#  'encephalopathy': <gensim.models.keyedvectors.Vocab at 0x1c85c891bc8>,
#  'dialysis': <gensim.models.keyedvectors.Vocab at 0x1c85c891c08>,
#  'arteriovenous': <gensim.models.keyedvectors.Vocab at 0x1c85c891d48>,
#  'graft': <gensim.models.keyedvectors.Vocab at 0x1c85c891308>,
#  'presentation': <gensim.models.keyedvectors.Vocab at 0x1c85c891908>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1c85c891808>,
#  'neurological': <gensim.models.keyedvectors.Vocab at 0x1c85c891848>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x1c85c891888>,
#  'challenging': <gensim.models.keyedvectors.Vocab at 0x1c85c891948>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1c85c8919c8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1c85c891a08>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x1c85c8912c8>,
#  'renal': <gensim.models.keyedvectors.Vocab at 0x1c85c891c48>,
#  'occipital': <gensim.models.keyedvectors.Vocab at 0x1c85c891c88>,
#  'infarction': <gensim.models.keyedvectors.Vocab at 0x1c85c891cc8>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x1c85c891d08>,
#  'progressive': <gensim.models.keyedvectors.Vocab at 0x1c85c8913c8>,
#  'intracranial': <gensim.models.keyedvectors.Vocab at 0x1c85c891408>,
#  'Extensive': <gensim.models.keyedvectors.Vocab at 0x1c85c891448>,
#  'electroencephalography': <gensim.models.keyedvectors.Vocab at 0x1c85c891488>,
#  'serum': <gensim.models.keyedvectors.Vocab at 0x1c85c8914c8>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1c85c891508>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x1c85c891548>,
#  'deterioration': <gensim.models.keyedvectors.Vocab at 0x1c85c891588>,
#  'angiography': <gensim.models.keyedvectors.Vocab at 0x1c85c891608>,
#  'venography': <gensim.models.keyedvectors.Vocab at 0x1c85c891648>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x1c85c891688>,
#  'generalized': <gensim.models.keyedvectors.Vocab at 0x1c85c8916c8>,
#  'shunting': <gensim.models.keyedvectors.Vocab at 0x1c85c891708>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x1c85c892048>,
#  'extremity': <gensim.models.keyedvectors.Vocab at 0x1c85c892088>,
#  'occluded': <gensim.models.keyedvectors.Vocab at 0x1c85c8920c8>,
#  'innominate': <gensim.models.keyedvectors.Vocab at 0x1c85c892108>,
#  'trunk': <gensim.models.keyedvectors.Vocab at 0x1c85c892148>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x1c85c892188>,
#  'shunt': <gensim.models.keyedvectors.Vocab at 0x1c85c8921c8>,
#  'hypertension': <gensim.models.keyedvectors.Vocab at 0x1c85c892208>,
#  'occlusion': <gensim.models.keyedvectors.Vocab at 0x1c85c892248>,
#  'repaired': <gensim.models.keyedvectors.Vocab at 0x1c85c892288>,
#  'resolved': <gensim.models.keyedvectors.Vocab at 0x1c85c8922c8>,
#  'returned': <gensim.models.keyedvectors.Vocab at 0x1c85c892308>,
#  'baseline': <gensim.models.keyedvectors.Vocab at 0x1c85c892348>,
#  'HIV': <gensim.models.keyedvectors.Vocab at 0x1c85c892388>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x1c85c8923c8>,
#  'affective': <gensim.models.keyedvectors.Vocab at 0x1c85c892408>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x1c85c892448>,
#  'caring': <gensim.models.keyedvectors.Vocab at 0x1c85c892488>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1c85c8924c8>,
#  'challenge': <gensim.models.keyedvectors.Vocab at 0x1c85c892508>,
#  'physicians': <gensim.models.keyedvectors.Vocab at 0x1c85c892548>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x1c85c892588>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1c85c8925c8>,
#  'workers': <gensim.models.keyedvectors.Vocab at 0x1c85c892608>,
#  'somatic': <gensim.models.keyedvectors.Vocab at 0x1c85c892648>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x1c85c892688>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x1c85c8926c8>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x1c85c892708>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x1c85c892748>,
#  'University': <gensim.models.keyedvectors.Vocab at 0x1c85c892788>,
#  'Teaching': <gensim.models.keyedvectors.Vocab at 0x1c85c8927c8>,
#  'Hospital': <gensim.models.keyedvectors.Vocab at 0x1c85c892808>,
#  'Lusaka': <gensim.models.keyedvectors.Vocab at 0x1c85c892848>,
#  'Zambia': <gensim.models.keyedvectors.Vocab at 0x1c85c892888>,
#  'satellite': <gensim.models.keyedvectors.Vocab at 0x1c85c8928c8>,
#  'clinics': <gensim.models.keyedvectors.Vocab at 0x1c85c892908>,
#  'Study': <gensim.models.keyedvectors.Vocab at 0x1c85c892948>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x1c85c892988>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x1c85c8929c8>,
#  'diagnosed': <gensim.models.keyedvectors.Vocab at 0x1c85c892a08>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x1c85c892a48>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x1c85c892a88>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x1c85c892ac8>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x1c85c892b08>,
#  'questionnaire': <gensim.models.keyedvectors.Vocab at 0x1c85c892b48>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1c85c892b88>,
#  'assess': <gensim.models.keyedvectors.Vocab at 0x1c85c892bc8>,
#  'psychological': <gensim.models.keyedvectors.Vocab at 0x1c85c892c08>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1c85c892c48>,
#  'majority': <gensim.models.keyedvectors.Vocab at 0x1c85c892c88>,
#  'depressive': <gensim.models.keyedvectors.Vocab at 0x1c85c892cc8>,
#  'episodes': <gensim.models.keyedvectors.Vocab at 0x1c85c892d08>,
#  'suicidal': <gensim.models.keyedvectors.Vocab at 0x1c85c892d48>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x1c85c892d88>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x1c85c892dc8>,
#  'illness': <gensim.models.keyedvectors.Vocab at 0x1c85c892e08>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1c85c892e48>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x1c85c892e88>,
#  'babies': <gensim.models.keyedvectors.Vocab at 0x1c85c892ec8>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x1c85c892f08>,
#  'liable': <gensim.models.keyedvectors.Vocab at 0x1c85c892f48>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1c85c892f88>,
#  'disorders': <gensim.models.keyedvectors.Vocab at 0x1c85c892fc8>,
#  'Physicians': <gensim.models.keyedvectors.Vocab at 0x1c85c893048>,
#  'dealing': <gensim.models.keyedvectors.Vocab at 0x1c85c893088>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1c85c8930c8>,
#  'cognisant': <gensim.models.keyedvectors.Vocab at 0x1c85c893108>,
#  'strain': <gensim.models.keyedvectors.Vocab at 0x1c85c893148>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x1c85c893188>,
#  'psychiatric': <gensim.models.keyedvectors.Vocab at 0x1c85c8931c8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1c85c893208>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x1c85c893248>,
#  'Risk': <gensim.models.keyedvectors.Vocab at 0x1c85c893288>,
#  'factors': <gensim.models.keyedvectors.Vocab at 0x1c85c8932c8>,
#  'cancer': <gensim.models.keyedvectors.Vocab at 0x1c85c893308>,
#  'oesophagus': <gensim.models.keyedvectors.Vocab at 0x1c85c893348>,
#  'Kerala': <gensim.models.keyedvectors.Vocab at 0x1c85c893388>,
#  'India': <gensim.models.keyedvectors.Vocab at 0x1c85c8933c8>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1c85c893408>,
#  'oesophageal': <gensim.models.keyedvectors.Vocab at 0x1c85c893448>,
#  'carried': <gensim.models.keyedvectors.Vocab at 0x1c85c893488>,
#  'Trivandrum': <gensim.models.keyedvectors.Vocab at 0x1c85c8934c8>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x1c85c893508>,
#  'controls': <gensim.models.keyedvectors.Vocab at 0x1c85c893548>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x1c85c893588>,
#  'pan': <gensim.models.keyedvectors.Vocab at 0x1c85c8935c8>,
#  'betel': <gensim.models.keyedvectors.Vocab at 0x1c85c893608>,
#  'tobacco': <gensim.models.keyedvectors.Vocab at 0x1c85c893648>,
#  'chewing': <gensim.models.keyedvectors.Vocab at 0x1c85c893688>,
#  'bidi': <gensim.models.keyedvectors.Vocab at 0x1c85c8936c8>,
#  'cigarette': <gensim.models.keyedvectors.Vocab at 0x1c85c893708>,
#  'smoking': <gensim.models.keyedvectors.Vocab at 0x1c85c893748>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x1c85c893788>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x1c85c8937c8>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x1c85c893808>,
#  'snuff': <gensim.models.keyedvectors.Vocab at 0x1c85c893848>,
#  'investigated': <gensim.models.keyedvectors.Vocab at 0x1c85c893888>,
#  'females': <gensim.models.keyedvectors.Vocab at 0x1c85c8938c8>,
#  'indulged': <gensim.models.keyedvectors.Vocab at 0x1c85c893908>,
#  'habits': <gensim.models.keyedvectors.Vocab at 0x1c85c893948>,
#  'Among': <gensim.models.keyedvectors.Vocab at 0x1c85c893988>,
#  'associations': <gensim.models.keyedvectors.Vocab at 0x1c85c8939c8>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x1c85c893a08>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x1c85c893a48>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x1c85c893a88>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x1c85c893ac8>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x1c85c893b08>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x1c85c893b48>,
#  'falling': <gensim.models.keyedvectors.Vocab at 0x1c85c893b88>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x1c85c893bc8>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1c85c893c08>,
#  'partly': <gensim.models.keyedvectors.Vocab at 0x1c85c893c48>,
#  'confounding': <gensim.models.keyedvectors.Vocab at 0x1c85c893c88>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x1c85c893cc8>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x1c85c893d08>,
#  'fitted': <gensim.models.keyedvectors.Vocab at 0x1c85c893d48>,
#  'retaining': <gensim.models.keyedvectors.Vocab at 0x1c85c893d88>,
#  'adjusted': <gensim.models.keyedvectors.Vocab at 0x1c85c893dc8>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x1c85c893e08>,
#  'frequency': <gensim.models.keyedvectors.Vocab at 0x1c85c893e48>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x1c85c893e88>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x1c85c893ec8>,
#  'habit': <gensim.models.keyedvectors.Vocab at 0x1c85c893f08>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1c85c893f48>,
#  'bidis': <gensim.models.keyedvectors.Vocab at 0x1c85c893f88>,
#  'cigarettes': <gensim.models.keyedvectors.Vocab at 0x1c85c893fc8>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x1c85c899048>,
#  'category': <gensim.models.keyedvectors.Vocab at 0x1c85c899088>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1c85c8990c8>,
#  'indulging': <gensim.models.keyedvectors.Vocab at 0x1c85c899108>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x1c85c899148>,
#  'nasocardiac': <gensim.models.keyedvectors.Vocab at 0x1c85c899188>,
#  'reflex': <gensim.models.keyedvectors.Vocab at 0x1c85c8991c8>,
#  'oculocardiac': <gensim.models.keyedvectors.Vocab at 0x1c85c899208>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x1c85c899248>,
#  'recognised': <gensim.models.keyedvectors.Vocab at 0x1c85c899288>,
#  'anaesthesia': <gensim.models.keyedvectors.Vocab at 0x1c85c8992c8>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1c85c899308>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x1c85c899348>,
#  'manifestation': <gensim.models.keyedvectors.Vocab at 0x1c85c899388>,
#  'anatomy': <gensim.models.keyedvectors.Vocab at 0x1c85c8993c8>,
#  'obtunded': <gensim.models.keyedvectors.Vocab at 0x1c85c899408>,
#  'Experimental': <gensim.models.keyedvectors.Vocab at 0x1c85c899448>,
#  'spinal': <gensim.models.keyedvectors.Vocab at 0x1c85c899488>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x1c85c8994c8>,
#  'ischemiathe': <gensim.models.keyedvectors.Vocab at 0x1c85c899508>,
#  'radical': <gensim.models.keyedvectors.Vocab at 0x1c85c899548>,
#  'scavengers': <gensim.models.keyedvectors.Vocab at 0x1c85c899588>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1c85c8995c8>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x1c85c899608>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x1c85c899648>,
#  'Using': <gensim.models.keyedvectors.Vocab at 0x1c85c899688>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x1c85c8996c8>,
#  'enzymatic': <gensim.models.keyedvectors.Vocab at 0x1c85c899708>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x1c85c899748>,
#  'superoxide': <gensim.models.keyedvectors.Vocab at 0x1c85c899788>,
#  'dismutase': <gensim.models.keyedvectors.Vocab at 0x1c85c8997c8>,
#  'catalase': <gensim.models.keyedvectors.Vocab at 0x1c85c899808>,
#  'glutathione': <gensim.models.keyedvectors.Vocab at 0x1c85c899848>,
#  'peroxidase': <gensim.models.keyedvectors.Vocab at 0x1c85c899888>,
#  'cords': <gensim.models.keyedvectors.Vocab at 0x1c85c8998c8>,
#  'evoked': <gensim.models.keyedvectors.Vocab at 0x1c85c899908>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x1c85c899948>,
#  'obtained': <gensim.models.keyedvectors.Vocab at 0x1c85c899988>,
#  'clamping': <gensim.models.keyedvectors.Vocab at 0x1c85c8999c8>,
#  'bilateral': <gensim.models.keyedvectors.Vocab at 0x1c85c899a08>,
#  'subclavian': <gensim.models.keyedvectors.Vocab at 0x1c85c899a48>,
#  'arteries': <gensim.models.keyedvectors.Vocab at 0x1c85c899a88>,
#  'aorta': <gensim.models.keyedvectors.Vocab at 0x1c85c899ac8>,
#  'distal': <gensim.models.keyedvectors.Vocab at 0x1c85c899b08>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x1c85c899b48>,
#  'artery': <gensim.models.keyedvectors.Vocab at 0x1c85c899b88>,
#  'Total': <gensim.models.keyedvectors.Vocab at 0x1c85c899bc8>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x1c85c899c08>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1c85c899c48>,
#  'ninth': <gensim.models.keyedvectors.Vocab at 0x1c85c899c88>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x1c85c899cc8>,
#  'Mn': <gensim.models.keyedvectors.Vocab at 0x1c85c899d08>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x1c85c899d48>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x1c85c899d88>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x1c85c899dc8>,
#  'ones': <gensim.models.keyedvectors.Vocab at 0x1c85c899e08>,
#  'decreased': <gensim.models.keyedvectors.Vocab at 0x1c85c899e48>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x1c85c899e88>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1c85c899ec8>,
#  'protection': <gensim.models.keyedvectors.Vocab at 0x1c85c899f08>,
#  'peroxidative': <gensim.models.keyedvectors.Vocab at 0x1c85c899f48>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x1c85c899f88>,
#  'reperfusion': <gensim.models.keyedvectors.Vocab at 0x1c85c899fc8>,
#  'Cadependent': <gensim.models.keyedvectors.Vocab at 0x1c85c89a588>,
#  'protease': <gensim.models.keyedvectors.Vocab at 0x1c85c89a5c8>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1c85c89a148>,
#  'decrease': <gensim.models.keyedvectors.Vocab at 0x1c85c89a3c8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1c85c89a508>,
#  'turnover': <gensim.models.keyedvectors.Vocab at 0x1c85c89a548>,
#  'enzyme': <gensim.models.keyedvectors.Vocab at 0x1c85c89a888>,
#  'summary': <gensim.models.keyedvectors.Vocab at 0x1c85c89a8c8>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x1c85c89a948>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1c85c89aa48>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1c85c89aa88>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x1c85c89ab08>,
#  'Ca': <gensim.models.keyedvectors.Vocab at 0x1c85c89ab48>,
#  'tissue': <gensim.models.keyedvectors.Vocab at 0x1c85c89ac08>,
#  'Reduction': <gensim.models.keyedvectors.Vocab at 0x1c85c89ac48>,
#  'QT': <gensim.models.keyedvectors.Vocab at 0x1c85c89ac88>,
#  'dispersion': <gensim.models.keyedvectors.Vocab at 0x1c85c89ae88>,
#  'ventricular': <gensim.models.keyedvectors.Vocab at 0x1c85c89aec8>,
#  'arrhythmias': <gensim.models.keyedvectors.Vocab at 0x1c85c89adc8>,
#  'ischaemic': <gensim.models.keyedvectors.Vocab at 0x1c85c89a048>,
#  'preconditioning': <gensim.models.keyedvectors.Vocab at 0x1c85c89a108>,
#  'anaesthetized': <gensim.models.keyedvectors.Vocab at 0x1c85c89a208>,
#  'normotensive': <gensim.models.keyedvectors.Vocab at 0x1c85c89a248>,
#  'spontaneously': <gensim.models.keyedvectors.Vocab at 0x1c85c89a288>,
#  'hypertensive': <gensim.models.keyedvectors.Vocab at 0x1c85c89a308>,
#  'marker': <gensim.models.keyedvectors.Vocab at 0x1c85c89a348>,
#  'repolarization': <gensim.models.keyedvectors.Vocab at 0x1c85c89a388>,
#  'electrical': <gensim.models.keyedvectors.Vocab at 0x1c85c89a448>,
#  'instability': <gensim.models.keyedvectors.Vocab at 0x1c85c89a488>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1c85c89a4c8>,
#  'However': <gensim.models.keyedvectors.Vocab at 0x1c85c89a608>,
#  'undocumented': <gensim.models.keyedvectors.Vocab at 0x1c85c89a648>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x1c85c89a6c8>,
#  'myocardial': <gensim.models.keyedvectors.Vocab at 0x1c85c89a708>,
#  'ischaemia': <gensim.models.keyedvectors.Vocab at 0x1c85c89a748>,
#  'ischrep': <gensim.models.keyedvectors.Vocab at 0x1c85c89ab88>,
# ...
#  'linked': <gensim.models.keyedvectors.Vocab at 0x1c85c88c108>,
#  'ecologic': <gensim.models.keyedvectors.Vocab at 0x1c85c88c148>,
#  'prospective': <gensim.models.keyedvectors.Vocab at 0x1c85c88c188>,
#  'Ecologic': <gensim.models.keyedvectors.Vocab at 0x1c85c88c1c8>,
#  'foods': <gensim.models.keyedvectors.Vocab at 0x1c85c88c208>,
#  'vitamin': <gensim.models.keyedvectors.Vocab at 0x1c85c88c248>,
#  'potassium': <gensim.models.keyedvectors.Vocab at 0x1c85c88c288>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x1c85c88c2c8>,
#  'inverse': <gensim.models.keyedvectors.Vocab at 0x1c85c88c308>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x1c85c88c348>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x1c85c88c388>,
#  'cohort': <gensim.models.keyedvectors.Vocab at 0x1c85c88c3c8>,
#  'Two': <gensim.models.keyedvectors.Vocab at 0x1c85c88c408>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x1c85c88c448>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1c85c88c488>,
#  'protective': <gensim.models.keyedvectors.Vocab at 0x1c85c88c4c8>,
#  'selenium': <gensim.models.keyedvectors.Vocab at 0x1c85c88c508>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x1c85c88c548>,
#  'Determination': <gensim.models.keyedvectors.Vocab at 0x1c85c88c588>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x1c85c88c5c8>,
#  'nutrients': <gensim.models.keyedvectors.Vocab at 0x1c85c88c608>,
#  'incidence': <gensim.models.keyedvectors.Vocab at 0x1c85c88c648>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x1c85c88c688>,
#  'tantalizing': <gensim.models.keyedvectors.Vocab at 0x1c85c88c6c8>,
#  'opportunities': <gensim.models.keyedvectors.Vocab at 0x1c85c88c708>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1c85c88c748>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x1c85c88c788>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x1c85c88c7c8>,
#  'intervention': <gensim.models.keyedvectors.Vocab at 0x1c85c88c808>,
#  'cholangitis': <gensim.models.keyedvectors.Vocab at 0x1c85c88c848>,
#  'biliary': <gensim.models.keyedvectors.Vocab at 0x1c85c88c888>,
#  'stasis': <gensim.models.keyedvectors.Vocab at 0x1c85c88c8c8>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1c85c88c908>,
#  'obstructive': <gensim.models.keyedvectors.Vocab at 0x1c85c88c948>,
#  'afferent': <gensim.models.keyedvectors.Vocab at 0x1c85c88c988>,
#  'loop': <gensim.models.keyedvectors.Vocab at 0x1c85c88c9c8>,
#  'pylorus': <gensim.models.keyedvectors.Vocab at 0x1c85c88ca08>,
#  'preserving': <gensim.models.keyedvectors.Vocab at 0x1c85c88ca48>,
#  'pancreatoduodenectomy': <gensim.models.keyedvectors.Vocab at 0x1c85c88ca88>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1c85c88cac8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1c85c88cb08>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1c85c88cb48>,
#  'undergone': <gensim.models.keyedvectors.Vocab at 0x1c85c88cb88>,
#  'IV': <gensim.models.keyedvectors.Vocab at 0x1c85c88cbc8>,
#  'reconstruction': <gensim.models.keyedvectors.Vocab at 0x1c85c88cc08>,
#  'cholangiocarcinoma': <gensim.models.keyedvectors.Vocab at 0x1c85c88cc48>,
#  'thereafter': <gensim.models.keyedvectors.Vocab at 0x1c85c88cc88>,
#  'suffered': <gensim.models.keyedvectors.Vocab at 0x1c85c88ccc8>,
#  'abscess': <gensim.models.keyedvectors.Vocab at 0x1c85c88cd08>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x1c85c88cd48>,
#  'percutaneous': <gensim.models.keyedvectors.Vocab at 0x1c85c88cd88>,
#  'drainage': <gensim.models.keyedvectors.Vocab at 0x1c85c88cdc8>,
#  'admitted': <gensim.models.keyedvectors.Vocab at 0x1c85c88ce08>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x1c85c88ce48>,
#  'purulent': <gensim.models.keyedvectors.Vocab at 0x1c85c88ce88>,
#  'referred': <gensim.models.keyedvectors.Vocab at 0x1c85c88cec8>,
#  'dilatation': <gensim.models.keyedvectors.Vocab at 0x1c85c88cf08>,
#  'intrahepatic': <gensim.models.keyedvectors.Vocab at 0x1c85c88cf48>,
#  'duct': <gensim.models.keyedvectors.Vocab at 0x1c85c88cf88>,
#  'Peroral': <gensim.models.keyedvectors.Vocab at 0x1c85c88cfc8>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x1c85c870048>,
#  'balloon': <gensim.models.keyedvectors.Vocab at 0x1c85c870088>,
#  'enteroscopy': <gensim.models.keyedvectors.Vocab at 0x1c85c8700c8>,
#  'revealed': <gensim.models.keyedvectors.Vocab at 0x1c85c870108>,
#  'diameter': <gensim.models.keyedvectors.Vocab at 0x1c85c870148>,
#  'hepaticojejunostomy': <gensim.models.keyedvectors.Vocab at 0x1c85c870188>,
#  'anastomosis': <gensim.models.keyedvectors.Vocab at 0x1c85c8701c8>,
#  'cholangiography': <gensim.models.keyedvectors.Vocab at 0x1c85c870208>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x1c85c870248>,
#  'stones': <gensim.models.keyedvectors.Vocab at 0x1c85c870288>,
#  'Lithotripsy': <gensim.models.keyedvectors.Vocab at 0x1c85c8702c8>,
#  'performed': <gensim.models.keyedvectors.Vocab at 0x1c85c870308>,
#  'basket': <gensim.models.keyedvectors.Vocab at 0x1c85c870348>,
#  'catheter': <gensim.models.keyedvectors.Vocab at 0x1c85c870388>,
#  'lithotripsy': <gensim.models.keyedvectors.Vocab at 0x1c85c8703c8>,
#  'Hepatobiliary': <gensim.models.keyedvectors.Vocab at 0x1c85c870408>,
#  'scintigraphy': <gensim.models.keyedvectors.Vocab at 0x1c85c870448>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x1c85c870488>,
#  'intravenous': <gensim.models.keyedvectors.Vocab at 0x1c85c8704c8>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x1c85c870508>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x1c85c870548>,
#  'tracer': <gensim.models.keyedvectors.Vocab at 0x1c85c870588>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1c85c8705c8>,
#  'remained': <gensim.models.keyedvectors.Vocab at 0x1c85c870608>,
#  'jejunum': <gensim.models.keyedvectors.Vocab at 0x1c85c870648>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x1c85c870688>,
#  'lithiasis': <gensim.models.keyedvectors.Vocab at 0x1c85c8706c8>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x1c85c870708>,
#  'nonobstructive': <gensim.models.keyedvectors.Vocab at 0x1c85c870748>,
#  'Biliary': <gensim.models.keyedvectors.Vocab at 0x1c85c870788>,
#  'retention': <gensim.models.keyedvectors.Vocab at 0x1c85c8707c8>,
#  'hepatobiliary': <gensim.models.keyedvectors.Vocab at 0x1c85c870808>,
#  'Protective': <gensim.models.keyedvectors.Vocab at 0x1c85c870848>,
#  'Codium': <gensim.models.keyedvectors.Vocab at 0x1c85c870888>,
#  'fragile': <gensim.models.keyedvectors.Vocab at 0x1c85c8708c8>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x1c85c870908>,
#  'ultravioletB': <gensim.models.keyedvectors.Vocab at 0x1c85c870948>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x1c85c870988>,
#  'oxidative': <gensim.models.keyedvectors.Vocab at 0x1c85c8709c8>,
#  'damages': <gensim.models.keyedvectors.Vocab at 0x1c85c870a08>,
#  'HaCaT': <gensim.models.keyedvectors.Vocab at 0x1c85c870a48>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x1c85c870a88>,
#  'BALB': <gensim.models.keyedvectors.Vocab at 0x1c85c870ac8>,
#  'mice': <gensim.models.keyedvectors.Vocab at 0x1c85c870b08>,
#  'Acute': <gensim.models.keyedvectors.Vocab at 0x1c85c870b48>,
#  'ultraviolet': <gensim.models.keyedvectors.Vocab at 0x1c85c870b88>,
#  'radiation': <gensim.models.keyedvectors.Vocab at 0x1c85c870bc8>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x1c85c870c08>,
#  'responses': <gensim.models.keyedvectors.Vocab at 0x1c85c870c48>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x1c85c870c88>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x1c85c870cc8>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x1c85c870d08>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1c85c870d48>,
#  'alga': <gensim.models.keyedvectors.Vocab at 0x1c85c870d88>,
#  'Codiales': <gensim.models.keyedvectors.Vocab at 0x1c85c870dc8>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1c85c870e08>,
#  'exhibit': <gensim.models.keyedvectors.Vocab at 0x1c85c870e48>,
#  'protozoal': <gensim.models.keyedvectors.Vocab at 0x1c85c870e88>,
#  'mycobacterial': <gensim.models.keyedvectors.Vocab at 0x1c85c870ec8>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x1c85c870f08>,
#  'vitro': <gensim.models.keyedvectors.Vocab at 0x1c85c870f48>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x1c85c870f88>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x1c85c870fc8>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6048>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6088>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x1c85c8a60c8>,
#  'buthanol': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6108>,
#  'ethylacetate': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6148>,
#  'fractions': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6188>,
#  'methanol': <gensim.models.keyedvectors.Vocab at 0x1c85c8a61c8>,
#  'extract': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6208>,
#  'CFB': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6248>,
#  'CFE': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6288>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x1c85c8a62c8>,
#  'compound': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6308>,
#  'clerosterol': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6348>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6388>,
#  'attenuated': <gensim.models.keyedvectors.Vocab at 0x1c85c8a63c8>,
#  'mJ': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6408>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6448>,
#  'cytotoxicity': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6488>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x1c85c8a64c8>,
#  'proteins': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6508>,
#  'cyclooxygenase': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6548>,
#  'inducible': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6588>,
#  'nitric': <gensim.models.keyedvectors.Vocab at 0x1c85c8a65c8>,
#  'oxide': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6608>,
#  'synthase': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6648>,
#  'initric': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6688>,
#  'oxideS': <gensim.models.keyedvectors.Vocab at 0x1c85c8a66c8>,
#  'Moreover': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6708>,
#  'effectively': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6748>,
#  'suppressed': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6788>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x1c85c8a67c8>,
#  'mediators': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6808>,
#  'prostaglandin': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6848>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6888>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x1c85c8a68c8>,
#  'topical': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6908>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6948>,
#  'irradiation': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6988>,
#  'inhibited': <gensim.models.keyedvectors.Vocab at 0x1c85c8a69c8>,
#  'Furthermore': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6a08>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6a48>,
#  'lipid': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6a88>,
#  'peroxidation': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6ac8>,
#  'carbonylation': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6b08>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6b48>,
#  'regulation': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6b88>,
#  'antioxidant': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6bc8>,
#  'defense': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6c08>,
#  'enzymes': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6c48>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6c88>,
#  'therapeutic': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6cc8>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6d08>,
#  'providing': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6d48>,
#  'Labio': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6d88>,
#  'glosso': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6dc8>,
#  'pharyngo': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6e08>,
#  'laryngeal': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6e48>,
#  'paralysis': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6e88>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6ec8>,
#  'lesions': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6f08>,
#  'cortical': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6f48>,
#  'subcortical': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6f88>,
#  'labio': <gensim.models.keyedvectors.Vocab at 0x1c85c8a6fc8>,
#  'peculiar': <gensim.models.keyedvectors.Vocab at 0x1c85c875048>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x1c85c875088>,
#  'CT': <gensim.models.keyedvectors.Vocab at 0x1c85c8750c8>,
#  'MRI': <gensim.models.keyedvectors.Vocab at 0x1c85c875108>,
#  'yielded': <gensim.models.keyedvectors.Vocab at 0x1c85c875148>,
#  'pseudobulbar': <gensim.models.keyedvectors.Vocab at 0x1c85c875188>,
#  'demonstrating': <gensim.models.keyedvectors.Vocab at 0x1c85c8751c8>,
#  'existence': <gensim.models.keyedvectors.Vocab at 0x1c85c875208>,
#  'corticobulbar': <gensim.models.keyedvectors.Vocab at 0x1c85c875248>,
#  'tract': <gensim.models.keyedvectors.Vocab at 0x1c85c875288>,
#  'opercular': <gensim.models.keyedvectors.Vocab at 0x1c85c8752c8>,
#  'opposite': <gensim.models.keyedvectors.Vocab at 0x1c85c875308>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x1c85c875348>,
#  'Personalized': <gensim.models.keyedvectors.Vocab at 0x1c85c875388>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x1c85c8753c8>,
#  'traumatic': <gensim.models.keyedvectors.Vocab at 0x1c85c875408>,
#  'Patients': <gensim.models.keyedvectors.Vocab at 0x1c85c875448>,
#  'sustained': <gensim.models.keyedvectors.Vocab at 0x1c85c875488>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x1c85c8754c8>,
#  'civilian': <gensim.models.keyedvectors.Vocab at 0x1c85c875508>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x1c85c875548>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x1c85c875588>,
#  'varying': <gensim.models.keyedvectors.Vocab at 0x1c85c8755c8>,
#  'severity': <gensim.models.keyedvectors.Vocab at 0x1c85c875608>,
#  'minimal': <gensim.models.keyedvectors.Vocab at 0x1c85c875648>,
#  'profound': <gensim.models.keyedvectors.Vocab at 0x1c85c875688>,
#  'functioning': <gensim.models.keyedvectors.Vocab at 0x1c85c8756c8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1c85c875708>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1c85c875748>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x1c85c875788>,
#  'subgroup': <gensim.models.keyedvectors.Vocab at 0x1c85c8757c8>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x1c85c875808>,
#  'neurobehavioral': <gensim.models.keyedvectors.Vocab at 0x1c85c875848>,
#  'sequelae': <gensim.models.keyedvectors.Vocab at 0x1c85c875888>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x1c85c8758c8>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x1c85c875908>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x1c85c875948>,
#  'persisting': <gensim.models.keyedvectors.Vocab at 0x1c85c875988>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1c85c8759c8>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x1c85c875a08>,
#  'microRNA': <gensim.models.keyedvectors.Vocab at 0x1c85c875a48>,
#  'peripheral': <gensim.models.keyedvectors.Vocab at 0x1c85c875a88>,
#  'mononuclear': <gensim.models.keyedvectors.Vocab at 0x1c85c875ac8>,
#  'reflect': <gensim.models.keyedvectors.Vocab at 0x1c85c875b08>,
#  'molecular': <gensim.models.keyedvectors.Vocab at 0x1c85c875b48>,
#  'alterations': <gensim.models.keyedvectors.Vocab at 0x1c85c875b88>,
#  'neurodegenerative': <gensim.models.keyedvectors.Vocab at 0x1c85c875bc8>,
#  'hypothesized': <gensim.models.keyedvectors.Vocab at 0x1c85c875c08>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1c85c875c48>,
#  'preclinical': <gensim.models.keyedvectors.Vocab at 0x1c85c875c88>,
#  'phases': <gensim.models.keyedvectors.Vocab at 0x1c85c875cc8>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1c85c875d08>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x1c85c875d48>,
#  'assessable': <gensim.models.keyedvectors.Vocab at 0x1c85c875d88>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x1c85c875dc8>,
#  ...}

# %%
word_vectors.most_similar('cerebral')
# Out:
# [('vasospasm', 0.8492591381072998),
#  ('microbleeds', 0.839863121509552),
#  ('hypoperfusion', 0.8316357135772705),
#  ('Cerebral', 0.8221175074577332),
#  ('Duret', 0.8086600303649902),
#  ('cranio', 0.7962836027145386),
#  ('infarct', 0.791989803314209),
#  ('ischaemic', 0.7911811470985413),
#  ('infarcts', 0.7869277000427246),
#  ('Mesenteric', 0.7867780923843384)]
